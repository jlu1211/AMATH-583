# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
q1 = pd.read_csv('/Users/chris/Library/CloudStorage/OneDrive-UW/4. Seinor/AMATH 583/HW/HW3/Problem 1/q1.csv')
q2 = pd.read_csv('/Users/chris/Library/CloudStorage/OneDrive-UW/4. Seinor/AMATH 583/HW/HW3/Problem 2/q2.csv')
q3 = pd.read_csv('/Users/chris/Library/CloudStorage/OneDrive-UW/4. Seinor/AMATH 583/HW/HW3/Problem 3/q3.csv')
# test = pd.read_csv('daxpy_perf.csv')

# %%
plt.figure(figsize=(12, 8))
plt.plot(q1['n'], q1['flops_per_sec'], label='DXAPY')
plt.plot(q2['n'], q2['flops_per_sec'], label='DGEMV')
plt.plot(q3['n'], q3['flops_per_sec'], label='DGEMM')

plt.xlabel('Vector/Matrix size n')
plt.ylabel('Average FLOPs per second')
plt.title('BLAS Performance vs Vector Size')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
